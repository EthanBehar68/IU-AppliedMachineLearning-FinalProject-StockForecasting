# %%
from fastquant import get_stock_data, backtest
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = get_stock_data("AAPL", "2001-03-26", "2021-03-26")
#print(df.head())
#print(df['open'][0])



res = backtest("smac", df, fast_period=range(15, 30, 3), slow_period=range(40, 55, 3), verbose=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# <img src="data:image/png;base64,..." width="2400">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-099505dd9930> in <module>
#      10
#      11
# ---> 12 res = backtest("smac", df, fast_period=range(15, 30, 3), slow_period=range(40, 55, 3), verbose=False)
#
# ~/Desktop/Indiana/Spring21/appliedML/P556FinalProject/proj_env/lib/python3.6/site-packages/fastquant/backtest/backtest.py in backtest(strategy, data, commission, init_cash, plot, verbose, sort_by, sentiments, strats, return_history, return_plot, channel, symbol, allow_short, short_max, figsize, data_class, data_kwargs, plot_kwargs, fig, **kwargs)
#     237                 return_plot=return_plot,
#     238                 plot_kwargs=plot_kwargs,
# --> 239                 **optim_params,
#     240             )
#     241         else:
#
# ValueError: too many values to unpack (expected 2)

# %%
print(res[['fast_period', 'slow_period', 'final_value']].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-743293e6a780> in <module>
# ----> 1 print(res[['fast_period', 'slow_period', 'final_value']].head())
#
# NameError: name 'res' is not defined
