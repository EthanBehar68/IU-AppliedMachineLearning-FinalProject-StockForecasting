# %%
### File Organization ###
# Imports
# RNN models classes
    # Simple RNN
    # Groovy (5 layer GRU model)
    # Loovy (5 layer LSTM model)
    # Super Groovy (8 layer GRU model)
    # Super Loovy (8 layer LSTM model)
# Graph plotting method
# Hyperparameters
# Data prep - get data from fastquant
# Data prep - helper methods and variables
# Train, predict methods
# Training/Predict Models
    # Simple RNN Apple - High column only
    # Groovy Apple - High column only
    # Loovy Apple - High column only
    # Super Groovy Apple - High column only
    # Super Loovy Apple - High column only
    # Simple RNN IBM - High column only
    # Groovy IBM - High column only
    # Loovy IBM - High column only
    # Super Groovy IBM - High column only
    # Super Loovy IBM - High column only

# %%
from fastquant import get_stock_data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, GRU, LSTM, Dropout
from keras.optimizers import RMSprop
# Out:
# Using TensorFlow backend.

# %%
# Build SimpleRNN Model

# 3 SimpleRNN layers with 32 inputs. Returns full sequence.
# 1 SimpleRNN layer with 32 inputs. Does not return full sequence
# 1 Dense layer with 1 input. 
# input -> 32 -> 32 -> 32 -> 32noFS -> 1
# Kernel Initializer: Glorot Uniform
# Recurrent Initializer: Orthogonal
# Bias Initializer: Zeross

# Builds a new instance of Simple RNN and scaler (if needed)
def build_simple_rnn(useDropout = True):
    scaler = MinMaxScaler(feature_range=(0,1))

    model = Sequential()
    model.add(SimpleRNN(32, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(SimpleRNN(32, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(SimpleRNN(32, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(SimpleRNN(32, return_sequences=False, activation=activation_funct))
    model.add(Dense(1, activation=activation_funct))

    optimizer = RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss=loss)

    return model, scaler

# %%
# Build Groovy Model

# 3 GRU layers with 50 inputs. Returns full sequence
# 1 GRU layer with 50 inputs. Does not return full sequence
# 1 Dense layer with 1 input.
# input -> 50 -> 50 -> 50 -> 50noFS ->1
# Kernel Initializer: Glorot Uniform
# Recurrent Initializer: Orthogonal
# Bias Initializer: Zeros

def build_groovy(useDropout = True):
    scaler = MinMaxScaler(feature_range=(0,1))

    model = Sequential()
    model.add(GRU(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(GRU(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(GRU(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(GRU(50, return_sequences=False, activation=activation_funct))
    model.add(Dense(1, activation=activation_funct))

    optimizer = RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss=loss)

    return model, scaler

# %%
# Build Loovy Model

# 3 LSTM layers with 50 inputs. Returns full sequence
# 1 LSTM layer with 50 inputs. Does not return full sequence
# 1 Dense layer with 1 input.
# input -> 50 -> 50 -> 50 -> 50noFS ->1
# Kernel Initializer: Glorot Uniform
# Recurrent Initializer: Orthogonal
# Bias Initializer: Zeros

def build_loovy(useDropout = True):
    scaler = MinMaxScaler(feature_range=(0,1))

    model = Sequential()
    model.add(LSTM(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(LSTM(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(LSTM(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(LSTM(50, return_sequences=False, activation=activation_funct))
    model.add(Dense(1, activation=activation_funct))

    optimizer = RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss=loss)

    return model, scaler

# %%
# Build SuperGroovy Model

# 6 GRU layers with 50 inputs. Returns full sequence
# 1 GRU layer with 50 inputs. Does not return full sequence
# 1 Dense layer with 1 input.
# input -> 50 -> 50 -> 50 -> 50noFS ->1
# Kernel Initializer: Glorot Uniform
# Recurrent Initializer: Orthogonal
# Bias Initializer: Zeros

def build_super_groovy(useDropout = True):
    scaler = MinMaxScaler(feature_range=(0,1))

    model = Sequential()
    model.add(GRU(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(GRU(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(GRU(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(GRU(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(GRU(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(GRU(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(GRU(50, return_sequences=False, activation=activation_funct))
    model.add(Dense(1, activation=activation_funct))

    optimizer = RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss=loss)

    return model, scaler

# %%
# Build SuperLoovy Model

# 6 LSTM layers with 50 inputs. Returns full sequence
# 1 LSTM layer with 50 inputs. Does not return full sequence
# 1 Dense layer with 1 input.
# input -> 50 -> 50 -> 50 -> 50noFS ->1
# Kernel Initializer: Glorot Uniform
# Recurrent Initializer: Orthogonal
# Bias Initializer: Zeros

def build_super_loovy(useDropout = True):
    scaler = MinMaxScaler(feature_range=(0,1))

    model = Sequential()
    model.add(LSTM(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(LSTM(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(LSTM(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(LSTM(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(LSTM(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(LSTM(50, return_sequences=True, activation=activation_funct))
    if useDropout: model.add(Dropout(dropout))
    model.add(LSTM(50, return_sequences=False, activation=activation_funct))
    model.add(Dense(1, activation=activation_funct))
   
    optimizer = RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss=loss)

    return model, scaler

# %%
# Plotting methods
def plot_results(preds, actual, title):
    fig, ax = plt.subplots(figsize=(15,5))
    ax.set_title(title)
    time = range(len(preds))
    ax.plot(time,preds,color='tab:red',marker='s',markersize=2,linestyle='-',linewidth=1,label='forcast')
    ax.plot(time,actual,color='tab:blue',marker='s',markersize=2,linestyle='-',linewidth=1,label='actual')
    ax.set_xlabel('time')
    ax.set_ylabel('stock price ($)')
    ax.set_xticks(np.arange(0,len(preds)+10,10))
    ax.set_xlim(0,len(preds)+10)
    ax.xaxis.grid(True,ls='--')
    ax.yaxis.grid(True,ls='--')
    ax.legend()
    fig.tight_layout()
    plt.savefig(f'../imgs/{title}.png', ext='png', bbox_inches="tight")  

colors = ['tab:red', 'tab:orange', 'tab:green', 'tab:purple', 'tab:pink', 'tab:cyan', 'tab:olive', 'tab:gray', 'tab:brown']
def multi_plot_results(preds, actual, titles, title):
    fig, ax = plt.subplots(figsize=(15,5))
    ax.set_title(title)
    time = range(len(actual))
    for i in range(len(preds)):
        ax.plot(time,preds[i],color=colors[i],marker='s',markersize=2,linestyle='-',linewidth=1,label=titles[i])
    ax.plot(time,actual,color='tab:blue',marker='D',markersize=2,linestyle='-',linewidth=1,label='actual')
    ax.set_xlabel('time')
    ax.set_ylabel('stock price ($)')
    ax.set_xticks(np.arange(0,len(actual)+10,10))
    ax.set_xlim(0,len(actual)+10)
    ax.xaxis.grid(True,ls='--')
    ax.yaxis.grid(True,ls='--')
    ax.legend()
    fig.tight_layout()
    plt.savefig(f'../imgs/{title}.png', ext='png', bbox_inches="tight")

multi_preds = []
multi_titles = []

# %%
# Hyperparameters

# Model Hyperparameters

learning_rate = 0.001
momentum = 0.9
optimizer = RMSprop(learning_rate=learning_rate)
loss = 'mean_absolute_percentage_error'
activation_funct = 'elu'
epochs = 100
batch_size = 150
dropout = 0.2

# Data Columns parameter (defaults to 'high' for both)
# Options: open high low close volume
# train_data_columns = ['close', 'volume']
# test_data_column = ['close']
train_data_columns = ['high']
test_data_column = ['high']

# Length of days to split data on
day_range = 60

# %%
# Data Prep - Get Data

full_apple_train = get_stock_data("AAPL", "2003-02-10", "2004-09-12")
last_59_train = full_apple_train[-(day_range-1):]
part_apple_test = get_stock_data("AAPL", "2004-09-13", "2005-01-22")
full_apple_test = last_59_train.append(part_apple_test)

full_ibm_train = get_stock_data("IBM", "2003-02-10", "2004-09-12")
last_59_train = full_ibm_train[-(day_range-1):]
part_ibm_test = get_stock_data("IBM", "2004-09-13", "2005-01-22")
full_ibm_test = last_59_train.append(part_ibm_test)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Data Prep - Helper Methods

# Extract high and normalize high data
def data_prep(in_train_data, in_test_data, scaler, data_columns=['high']):
    train_data = in_train_data[data_columns].values
    # train_data = train_data.reshape(-1,1)
    train_scale = scaler.fit_transform(train_data)

    test_data = in_test_data[data_columns].values
    # test_data = test_data.reshape(-1,1)
    test_scale = scaler.transform(test_data)

    return train_scale, test_scale, scaler

# Split train/test data into x/y sets
# For single column i.e. like high only
def get_xy_train_sets(train_data):
    X_train = []
    Y_train = []

    for i in range(day_range, len(train_data)):
        X_train.append(train_data[i-day_range:i, 0])
        Y_train.append(train_data[i,0])

    x_train, y_train = np.array(X_train), np.array(Y_train)
    x_train = np.reshape(x_train, (*x_train.shape, 1))

    return x_train, y_train

def get_xy_test_sets(scaled_test_data, raw_test_data, data_column='high'):
    X_test = []
    for i in range(day_range, len(scaled_test_data)):
        X_test.append(scaled_test_data[i-day_range:i, 0])

    x_test = np.array(X_test)
    x_test = np.reshape(x_test, (*x_test.shape, 1))

    test_data = raw_test_data[data_column].values
    
    Y_test = []
    for i in range(day_range, len(test_data)):
        Y_test.append(test_data[i])
    
    y_test = np.array(Y_test)

    return x_test, y_test

# %%
# Train, predict methods

def train(model, in_epochs, in_batch_size):
    model.fit(x_train, y_train, epochs=in_epochs, batch_size=in_batch_size)
    return model

def predict(model, x_test, scaler):
    scaled_predictions = model.predict(x_test)

    # https://stackoverflow.com/questions/42997228/lstm-keras-error-valueerror-non-broadcastable-output-operand-with-shape-67704
    fitted_scaled_predictions = np.zeros(shape=(len(scaled_predictions), len(train_data_columns)))
    fitted_scaled_predictions[:,0] = scaled_predictions[:,0]
    test_predictions = scaler.inverse_transform(fitted_scaled_predictions )[:,0]

    return test_predictions

# %%
# Apple
print('Starting Simple RNN MAPE - Apple using ', train_data_columns)
rnn, scaler = build_simple_rnn()

train_scale, test_scale, scaler = data_prep(full_apple_train, full_apple_test, scaler, train_data_columns)
x_train, y_train = get_xy_train_sets(train_scale)
x_test, y_test = get_xy_test_sets(test_scale, full_apple_test, test_data_column)

rnn = train(rnn, epochs, batch_size)
y_preds = predict(rnn, x_test, scaler)

plot_results(y_preds, y_test, 'Simple RNN MAPE - Apple using ' + str(test_data_column))

multi_preds.append(y_preds)
multi_titles.append('SimpleRNN')
# Out:
# Starting Simple RNN MAPE - Apple using  ['high']
# Epoch 1/100
# 340/340 [==============================] - 1s 3ms/step - loss: 209.0150
# Epoch 2/100
# Epoch 79/100
# 340/340 [==============================] - 0s 508us/step - loss: 18.2515
# Epoch 80/100
# 340/340 [==============================] - 0s 486us/step - loss: 19.0563
# Epoch 81/100
# 340/340 [==============================] - 0s 482us/step - loss: 19.8451
# Epoch 82/100
# 340/340 [==============================] - 0s 515us/step - loss: 17.3545
# Epoch 83/100
# 340/340 [==============================] - 0s 488us/step - loss: 15.7718
# Epoch 84/100
# 340/340 [==============================] - 0s 485us/step - loss: 18.9964
# Epoch 85/100
# 340/340 [==============================] - 0s 488us/step - loss: 12.2860
# Epoch 86/100
# 340/340 [==============================] - 0s 500us/step - loss: 19.0204
# Epoch 87/100
# 340/340 [==============================] - 0s 476us/step - loss: 11.1497
# Epoch 88/100
# 340/340 [==============================] - 0s 473us/step - loss: 23.2431
# Epoch 89/100
# 340/340 [==============================] - 0s 482us/step - loss: 16.3770
# Epoch 90/100
# 340/340 [==============================] - 0s 473us/step - loss: 14.9164
# Epoch 91/100
# 340/340 [==============================] - 0s 469us/step - loss: 19.0928
# Epoch 92/100
# 340/340 [==============================] - 0s 473us/step - loss: 12.4252
# Epoch 93/100
# 340/340 [==============================] - 0s 470us/step - loss: 16.1201
# Epoch 94/100
# 340/340 [==============================] - 0s 482us/step - loss: 17.3523
# Epoch 95/100
# 340/340 [==============================] - 0s 475us/step - loss: 14.9117
# Epoch 96/100
# 340/340 [==============================] - 0s 570us/step - loss: 15.5470
# Epoch 97/100
# 340/340 [==============================] - 0s 476us/step - loss: 12.9484
# Epoch 98/100
# 340/340 [==============================] - 0s 484us/step - loss: 18.2532
# Epoch 99/100
# 340/340 [==============================] - 0s 488us/step - loss: 15.7293
# Epoch 100/100
# 340/340 [==============================] - 0s 479us/step - loss: 10.3649

# %%
# Apple
print('Starting Groovy RNN MAPE - Apple using ', train_data_columns)
rnn, scaler = build_groovy()

train_scale, test_scale, scaler = data_prep(full_apple_train, full_apple_test, scaler, train_data_columns)
x_train, y_train = get_xy_train_sets(train_scale)
x_test, y_test = get_xy_test_sets(test_scale, full_apple_test)

rnn = train(rnn, epochs, batch_size)
y_preds = predict(rnn, x_test, scaler)

plot_results(y_preds, y_test, 'Groovy MAPE - Apple using ' + str(test_data_column))

multi_preds.append(y_preds)
multi_titles.append('Groovy')
# Out:
# Starting Groovy RNN MAPE - Apple using  ['high']
# Epoch 1/100
# 340/340 [==============================] - 2s 6ms/step - loss: 71.6242
# Epoch 2/100
# 340/340 [==============================] - 1s 2ms/step - loss: 27.3197
# Epoch 3/100
# 340/340 [==============================] - 1s 2ms/step - loss: 28.2477
# Epoch 4/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.6040
# Epoch 5/100
# 340/340 [==============================] - 1s 2ms/step - loss: 20.8608
# Epoch 6/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.2636
# Epoch 7/100
# 340/340 [==============================] - 1s 2ms/step - loss: 18.7078
# Epoch 8/100
# 340/340 [==============================] - 1s 2ms/step - loss: 18.8530
# Epoch 9/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.1090
# Epoch 10/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.2527
# Epoch 11/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.1160
# Epoch 12/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.2521
# Epoch 13/100
# 340/340 [==============================] - 1s 2ms/step - loss: 21.4737
# Epoch 14/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.3091
# Epoch 15/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.9765
# Epoch 16/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.0930
# Epoch 17/100
# 340/340 [==============================] - 1s 2ms/step - loss: 18.2071
# Epoch 18/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.7215
# Epoch 19/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.3361
# Epoch 20/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.7647
# Epoch 21/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.1921
# Epoch 22/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.3654
# Epoch 23/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.4051
# Epoch 24/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.3534
# Epoch 25/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.7032
# Epoch 26/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.0992
# Epoch 27/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.5857
# Epoch 28/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.5432
# Epoch 29/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.2907
# Epoch 30/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.8314
# Epoch 31/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.1467
# Epoch 32/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.9331
# Epoch 33/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.1455
# Epoch 34/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.9778
# Epoch 35/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.4878
# Epoch 36/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.7925
# Epoch 37/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.1461
# Epoch 38/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.6010
# Epoch 39/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.5727
# Epoch 40/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.1915
# Epoch 41/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.0406
# Epoch 42/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.0849
# Epoch 43/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.0886
# Epoch 44/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.5916
# Epoch 45/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.8793
# Epoch 46/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.6944
# Epoch 47/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.3614
# Epoch 48/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.4497
# Epoch 49/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.6282
# Epoch 50/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.1161
# Epoch 51/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.9536
# Epoch 52/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.8350
# Epoch 53/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.0225
# Epoch 54/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.8848
# Epoch 55/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.6029
# Epoch 56/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.8957
# Epoch 57/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.8765
# Epoch 58/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.1404
# Epoch 59/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.6550
# Epoch 60/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.1383
# Epoch 61/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.4769
# Epoch 62/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.9198
# Epoch 63/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.2045
# Epoch 64/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.9629
# Epoch 65/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.8921
# Epoch 66/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.5245
# Epoch 67/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.7500
# Epoch 68/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.4767
# Epoch 69/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.4982
# Epoch 70/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.0408
# Epoch 71/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.4705
# Epoch 72/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.4351
# Epoch 73/100
# 340/340 [==============================] - 1s 2ms/step - loss: 8.8476
# Epoch 74/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.2201
# Epoch 75/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.7691
# Epoch 76/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.2011
# Epoch 77/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.3896
# Epoch 78/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.5308
# Epoch 79/100
# 340/340 [==============================] - 1s 2ms/step - loss: 8.4198
# Epoch 80/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.5865
# Epoch 81/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.8249
# Epoch 82/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.1397
# Epoch 83/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.8562
# Epoch 84/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.5738
# Epoch 85/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.2196
# Epoch 86/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.2749
# Epoch 87/100
# 340/340 [==============================] - 1s 2ms/step - loss: 8.6503
# Epoch 88/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.4184
# Epoch 89/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.8888
# Epoch 90/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.4242
# Epoch 91/100
# 340/340 [==============================] - 1s 2ms/step - loss: 8.0296
# Epoch 92/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.2447
# Epoch 93/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.6416
# Epoch 94/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.8780
# Epoch 95/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.2110
# Epoch 96/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.0235
# Epoch 97/100
# 340/340 [==============================] - 1s 2ms/step - loss: 7.8043
# Epoch 98/100
# 340/340 [==============================] - 1s 2ms/step - loss: 8.8763
# Epoch 99/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.2150
# Epoch 100/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.9758

# %%
# Apple
print('Starting Loovy RNN MAPE - Apple using ', train_data_columns)
rnn, scaler = build_loovy()

train_scale, test_scale, scaler = data_prep(full_apple_train, full_apple_test, scaler, train_data_columns)
x_train, y_train = get_xy_train_sets(train_scale)
x_test, y_test = get_xy_test_sets(test_scale, full_apple_test)

rnn = train(rnn, epochs, batch_size)
y_preds = predict(rnn, x_test, scaler)

plot_results(y_preds, y_test, 'Loovy MAPE - Apple using ' + str(test_data_column))

# multi_preds.append(y_preds)
# multi_titles.append('Loovy')
# Out:
# Starting Loovy RNN MAPE - Apple using  ['high']
# Epoch 1/100
# 340/340 [==============================] - 2s 5ms/step - loss: 76.9773
# Epoch 2/100
# 340/340 [==============================] - 1s 2ms/step - loss: 37.6055
# Epoch 3/100
# 340/340 [==============================] - 1s 2ms/step - loss: 25.1818
# Epoch 4/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.5591
# Epoch 5/100
# 340/340 [==============================] - 1s 2ms/step - loss: 24.8175
# Epoch 6/100
# 340/340 [==============================] - 1s 2ms/step - loss: 21.9289
# Epoch 7/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.6493
# Epoch 8/100
# 340/340 [==============================] - 1s 2ms/step - loss: 34.2396
# Epoch 9/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.3366
# Epoch 10/100
# 340/340 [==============================] - 1s 2ms/step - loss: 21.2742
# Epoch 11/100
# 340/340 [==============================] - 1s 2ms/step - loss: 20.9479
# Epoch 12/100
# 340/340 [==============================] - 1s 2ms/step - loss: 22.8156
# Epoch 13/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.3002
# Epoch 14/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.7282
# Epoch 15/100
# 340/340 [==============================] - 1s 2ms/step - loss: 20.7620
# Epoch 16/100
# 340/340 [==============================] - 1s 2ms/step - loss: 19.1490
# Epoch 17/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.9673
# Epoch 18/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.2541
# Epoch 19/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.9465
# Epoch 20/100
# 340/340 [==============================] - 1s 2ms/step - loss: 22.2233
# Epoch 21/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.1638
# Epoch 22/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.7172
# Epoch 23/100
# 340/340 [==============================] - 1s 2ms/step - loss: 19.3943
# Epoch 24/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.3899
# Epoch 25/100
# 340/340 [==============================] - 1s 2ms/step - loss: 18.0979
# Epoch 26/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.9537
# Epoch 27/100
# 340/340 [==============================] - 1s 2ms/step - loss: 20.1685
# Epoch 28/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.4391
# Epoch 29/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.7311
# Epoch 30/100
# 340/340 [==============================] - 1s 2ms/step - loss: 19.7929
# Epoch 31/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.2100
# Epoch 32/100
# 340/340 [==============================] - 1s 2ms/step - loss: 19.9255
# Epoch 33/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.4409
# Epoch 34/100
# 340/340 [==============================] - 1s 2ms/step - loss: 19.1174
# Epoch 35/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.4900
# Epoch 36/100
# 340/340 [==============================] - 1s 2ms/step - loss: 18.3100
# Epoch 37/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.5300
# Epoch 38/100
# 340/340 [==============================] - 1s 2ms/step - loss: 18.0654
# Epoch 39/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.8553
# Epoch 40/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.4010
# Epoch 41/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.8616
# Epoch 42/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.4190
# Epoch 43/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.3126
# Epoch 44/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.3445
# Epoch 45/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.3469
# Epoch 46/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.9401
# Epoch 47/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.1010
# Epoch 48/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.1582
# Epoch 49/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.2513
# Epoch 50/100
# 340/340 [==============================] - 1s 2ms/step - loss: 19.9050
# Epoch 51/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.0424
# Epoch 52/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.0985
# Epoch 53/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.8342
# Epoch 54/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.7274
# Epoch 55/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.1061
# Epoch 56/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.8377
# Epoch 57/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.5432
# Epoch 58/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.8848
# Epoch 59/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.1659
# Epoch 60/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.9504
# Epoch 61/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.4171
# Epoch 62/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.4737
# Epoch 63/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.9152
# Epoch 64/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.5513
# Epoch 65/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.3872
# Epoch 66/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.0169
# Epoch 67/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.8537
# Epoch 68/100
# 340/340 [==============================] - 1s 2ms/step - loss: 18.0013
# Epoch 69/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.8737
# Epoch 70/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.5507
# Epoch 71/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.9982
# Epoch 72/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.1369
# Epoch 73/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.5728
# Epoch 74/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.3727
# Epoch 75/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.8026
# Epoch 76/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.2461
# Epoch 77/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.5566
# Epoch 78/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.8919
# Epoch 79/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15.4091
# Epoch 80/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.7437
# Epoch 81/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.4181
# Epoch 82/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.1600
# Epoch 83/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.3048
# Epoch 84/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.9747
# Epoch 85/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.6562
# Epoch 86/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.5796
# Epoch 87/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.3272
# Epoch 88/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.1356
# Epoch 89/100
# 340/340 [==============================] - 1s 2ms/step - loss: 8.8276
# Epoch 90/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.6534
# Epoch 91/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.1132
# Epoch 92/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.2685
# Epoch 93/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.2961
# Epoch 94/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.2708
# Epoch 95/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.5512
# Epoch 96/100
# 340/340 [==============================] - 1s 2ms/step - loss: 12.2917
# Epoch 97/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.5960
# Epoch 98/100
# 340/340 [==============================] - 1s 2ms/step - loss: 11.0919
# Epoch 99/100
# 340/340 [==============================] - 1s 2ms/step - loss: 9.7931
# Epoch 100/100
# 340/340 [==============================] - 1s 2ms/step - loss: 14.2277

# %%
# Apple
print('Starting Super Groovy RNN MAPE - Apple using ', train_data_columns)
rnn, scaler = build_super_groovy()

train_scale, test_scale, scaler = data_prep(full_apple_train, full_apple_test, scaler, train_data_columns)
x_train, y_train = get_xy_train_sets(train_scale)
x_test, y_test = get_xy_test_sets(test_scale, full_apple_test)

rnn = train(rnn, epochs, batch_size)
y_preds = predict(rnn, x_test, scaler)

plot_results(y_preds, y_test, 'Super Groovy MAPE - Apple using ' + str(test_data_column))

multi_preds.append(y_preds)
multi_titles.append('SGroovy')
# Out:
# Starting Super Groovy RNN MAPE - Apple using  ['high']
# Epoch 1/100
# 340/340 [==============================] - 4s 11ms/step - loss: 80.6728
# Epoch 2/100
# 340/340 [==============================] - 1s 3ms/step - loss: 43.9852
# Epoch 3/100
# 340/340 [==============================] - 1s 4ms/step - loss: 35.6058
# Epoch 4/100
# 340/340 [==============================] - 1s 4ms/step - loss: 20.8421
# Epoch 5/100
# 340/340 [==============================] - 1s 3ms/step - loss: 24.3393
# Epoch 6/100
# 340/340 [==============================] - 1s 3ms/step - loss: 23.4312
# Epoch 7/100
# 340/340 [==============================] - 1s 3ms/step - loss: 26.4194
# Epoch 8/100
# 340/340 [==============================] - 1s 4ms/step - loss: 26.3288
# Epoch 9/100
# 340/340 [==============================] - 1s 3ms/step - loss: 16.6777
# Epoch 10/100
# 340/340 [==============================] - 1s 3ms/step - loss: 26.4725
# Epoch 11/100
# 340/340 [==============================] - 1s 3ms/step - loss: 18.5363
# Epoch 12/100
# 340/340 [==============================] - 1s 3ms/step - loss: 22.0205
# Epoch 13/100
# 340/340 [==============================] - 1s 4ms/step - loss: 20.5788
# Epoch 14/100
# 340/340 [==============================] - 1s 4ms/step - loss: 18.3820
# Epoch 15/100
# 340/340 [==============================] - 1s 4ms/step - loss: 20.2856
# Epoch 16/100
# 340/340 [==============================] - 1s 3ms/step - loss: 19.7591
# Epoch 17/100
# 340/340 [==============================] - 1s 3ms/step - loss: 21.6224
# Epoch 18/100
# 340/340 [==============================] - 1s 4ms/step - loss: 17.9691
# Epoch 19/100
# 340/340 [==============================] - 1s 4ms/step - loss: 19.1098
# Epoch 20/100
# 340/340 [==============================] - 1s 3ms/step - loss: 20.8569
# Epoch 21/100
# 340/340 [==============================] - 1s 3ms/step - loss: 18
100
# 340/340 [==============================] - 1s 3ms/step - loss: 13.0082
# Epoch 85/100
# 340/340 [==============================] - 1s 3ms/step - loss: 10.7281
# Epoch 86/100
# 340/340 [==============================] - 1s 3ms/step - loss: 12.9892
# Epoch 87/100
# 340/340 [==============================] - 1s 3ms/step - loss: 8.8745
# Epoch 88/100
# 340/340 [==============================] - 1s 4ms/step - loss: 14.6331
# Epoch 89/100
# 340/340 [==============================] - 1s 3ms/step - loss: 10.9196
# Epoch 90/100
# 340/340 [==============================] - 1s 3ms/step - loss: 11.9453
# Epoch 91/100
# 340/340 [==============================] - 1s 3ms/step - loss: 14.7486
# Epoch 92/100
# 340/340 [==============================] - 1s 3ms/step - loss: 11.7580
# Epoch 93/100
# 340/340 [==============================] - 1s 4ms/step - loss: 11.7812
# Epoch 94/100
# 340/340 [==============================] - 1s 3ms/step - loss: 10.3310
# Epoch 95/100
# 340/340 [==============================] - 1s 3ms/step - loss: 8.8632
# Epoch 96/100
# 340/340 [==============================] - 1s 3ms/step - loss: 13.6389
# Epoch 97/100
# 340/340 [==============================] - 1s 3ms/step - loss: 9.9133
# Epoch 98/100
# 340/340 [==============================] - 1s 4ms/step - loss: 12.2538
# Epoch 99/100
# 340/340 [==============================] - 1s 3ms/step - loss: 13.2944
# Epoch 100/100
# 340/340 [==============================] - 1s 3ms/step - loss: 8.3639

# %%
# Apple
print('Starting Super Loovy RNN MAPE - Apple using ', train_data_columns)
rnn, scaler = build_super_loovy()

train_scale, test_scale, scaler = data_prep(full_apple_train, full_apple_test, scaler, train_data_columns)
x_train, y_train = get_xy_train_sets(train_scale)
x_test, y_test = get_xy_test_sets(test_scale, full_apple_test)

rnn = train(rnn, epochs, batch_size)
y_preds = predict(rnn, x_test, scaler)

plot_results(y_preds, y_test, 'Super Loovy MAPE - Apple using ' + str(test_data_column))

# multi_preds.append(y_preds)
# multi_titles.append('SLoovy')
# Out:
# Starting Super Loovy RNN MAPE - Apple using  ['high']
# Epoch 1/100
# 340/340 [==============================] - 3s 10ms/step - loss: 83.9208
# Epoch 2/100
# 340/340 [==============================] - 1s 4ms/step - loss: 154.8835
# Epoch 3/100
# 340/340 [==============================] - 1s 4ms/step - loss: 23.2701
# Epoch 4/100
# 340/340 [==============================] - 1s 4ms/step - loss: 21.9077
# Epoch 5/100
# 340/340 [==============================] - 1s 4ms/step - loss: 24.2673
# Epoch 6/100
# 340/340 [==============================] - 1s 4ms/step - loss: 24.1860
# Epoch 7/100
# 340/340 [==============================] - 1s 4ms/step - loss: 23.8865
# Epoch 8/100
# 340/340 [==============================] - 1s 4ms/step - loss: 29.6926
# Epoch 9/100
# 340/340 [==============================] - 1s 4ms/step - loss: 22.4817
# Epoch 10/100
# 340/340 [==============================] - 1s 4ms/step - loss: 28.9120
# Epoch 11/100
# 340/340 [==============================] - 1s 4ms/step - loss: 16.2944
# Epoch 12/100
# 340/340 [==============================] - 1s 4ms/step - loss: 43.3213
# Epoch 13/100
# 340/340 [==============================] - 1s 4ms/step - loss: 16.7738
# Epoch 14/100
# 340/340 [==============================] - 1s 4ms/step - loss: 25.1415
# Epoch 15/100
# 340/340 [==============================] - 1s 4ms/step - loss: 16.1281
# Epoch 16/100
# 340/340 [==============================] - 2s 5ms/step - loss: 40.9872
# Epoch 17/100
# 340/340 [==============================] - 2s 5ms/step - loss: 22.6651
# Epoch 18/100
# 340/340 [==============================] - 2s 5ms/step - loss: 16.4886
# Epoch 19/100
# 340/340 [==============================] - 2s 4ms/step - loss: 29.1085
# Epoch 20/100
# 340/340 [==============================] - 1s 4ms/step - loss: 19.9609
# Epoch 21/100
# 340/340 [==============================] - 2s 4ms/step - loss: 24.6454
# Epoch 22/100
# 340/340 [==============================] - 2s 5ms/step - loss: 17
100
# 340/340 [==============================] - 1s 4ms/step - loss: 18.8660
# Epoch 67/100
# 340/340 [==============================] - 2s 5ms/step - loss: 12.8212
# Epoch 68/100
# 340/340 [==============================] - 2s 5ms/step - loss: 19.7283
# Epoch 69/100
# 340/340 [==============================] - 2s 5ms/step - loss: 15.5976
# Epoch 70/100
# 340/340 [==============================] - 2s 5ms/step - loss: 16.0242
# Epoch 71/100
# 340/340 [==============================] - 1s 4ms/step - loss: 15.4058
# Epoch 72/100
# 340/340 [==============================] - 2s 5ms/step - loss: 14.5345
# Epoch 73/100
# 340/340 [==============================] - 2s 5ms/step - loss: 18.0680
# Epoch 74/100
# 340/340 [==============================] - 2s 5ms/step - loss: 17.5570
# Epoch 75/100
# 340/340 [==============================] - 2s 5ms/step - loss: 13.5416
# Epoch 76/100
# 340/340 [==============================] - 1s 4ms/step - loss: 15.2765
# Epoch 77/100
# 340/340 [==============================] - 1s 4ms/step - loss: 12.6476
# Epoch 78/100
# 340/340 [==============================] - 2s 5ms/step - loss: 13.4435
# Epoch 79/100
# 340/340 [==============================] - 2s 5ms/step - loss: 17.2991
# Epoch 80/100
# 340/340 [==============================] - 2s 5ms/step - loss: 15.7883
# Epoch 81/100
# 340/340 [==============================] - 2s 5ms/step - loss: 12.8106
# Epoch 82/100
# 340/340 [==============================] - 1s 4ms/step - loss: 22.4932
# Epoch 83/100
# 340/340 [==============================] - 2s 4ms/step - loss: 12.3926
# Epoch 84/100
# 340/340 [==============================] - 2s 5ms/step - loss: 13.5264
# Epoch 85/100
# 340/340 [==============================] - 2s 5ms/step - loss: 13.5096
# Epoch 86/100
# 340/340 [==============================] - 2s 5ms/step - loss: 18.9530
# Epoch 87/100
# 340/340 [==============================] - 2s 4ms/step - loss: 14.5473
# Epoch 88/100
# 340/340 [==============================] - 1s 4ms/step - loss: 14.7997
# Epoch 89/100
# 340/340 [==============================] - 2s 5ms/step - loss: 14.5476
# Epoch 90/100
# 340/340 [==============================] - 2s 5ms/step - loss: 12.6572
# Epoch 91/100
# 340/340 [==============================] - 2s 5ms/step - loss: 14.4494
# Epoch 92/100
# 340/340 [==============================] - 2s 5ms/step - loss: 17.5567
# Epoch 93/100
# 340/340 [==============================] - 1s 4ms/step - loss: 13.3791
# Epoch 94/100
# 340/340 [==============================] - 1s 4ms/step - loss: 13.4192
# Epoch 95/100
# 340/340 [==============================] - 2s 5ms/step - loss: 12.8429
# Epoch 96/100
# 340/340 [==============================] - 2s 5ms/step - loss: 18.6133
# Epoch 97/100
# 340/340 [==============================] - 2s 5ms/step - loss: 11.4786
# Epoch 98/100
# 340/340 [==============================] - 2s 5ms/step - loss: 21.1827
# Epoch 99/100
# 340/340 [==============================] - 1s 4ms/step - loss: 14.0051
# Epoch 100/100
# 340/340 [==============================] - 1s 4ms/step - loss: 16.7787

# %%
multi_plot_results(multi_preds, y_test, multi_titles, 'Apple using ' + str(test_data_column))

# %%
multi_preds = []
multi_titles = []

# %%
# IBM
print('Starting Simple RNN MAPE - IBM using ', train_data_columns)
rnn, scaler = build_simple_rnn()

train_scale, test_scale, scaler = data_prep(full_ibm_train, full_ibm_test, scaler, train_data_columns)
x_train, y_train = get_xy_train_sets(train_scale)
x_test, y_test = get_xy_test_sets(test_scale, full_ibm_test)

rnn = train(rnn, epochs, batch_size)
y_preds = predict(rnn, x_test, scaler)

plot_results(y_preds, y_test, 'Simple RNN MAPE - IBM using ' + str(test_data_column))

multi_preds.append(y_preds)
multi_titles.append('SimpleRNN')
# Out:
# Starting Simple RNN MAPE - IBM using  ['high']
# Epoch 1/100
# 340/340 [==============================] - 1s 2ms/step - loss: 192.8348
# Epoch 2/100
# Epoch 79/100
# 340/340 [==============================] - 0s 447us/step - loss: 14.3087
# Epoch 80/100
# 340/340 [==============================] - 0s 447us/step - loss: 13.6516
# Epoch 81/100
# 340/340 [==============================] - 0s 450us/step - loss: 16.1229
# Epoch 82/100
# 340/340 [==============================] - 0s 479us/step - loss: 16.4986
# Epoch 83/100
# 340/340 [==============================] - 0s 450us/step - loss: 15.1472
# Epoch 84/100
# 340/340 [==============================] - 0s 450us/step - loss: 12.7399
# Epoch 85/100
# 340/340 [==============================] - 0s 450us/step - loss: 14.2076
# Epoch 86/100
# 340/340 [==============================] - 0s 455us/step - loss: 12.8933
# Epoch 87/100
# 340/340 [==============================] - 0s 453us/step - loss: 16.3536
# Epoch 88/100
# 340/340 [==============================] - 0s 450us/step - loss: 15.4357
# Epoch 89/100
# 340/340 [==============================] - 0s 444us/step - loss: 12.4613
# Epoch 90/100
# 340/340 [==============================] - 0s 453us/step - loss: 13.5330
# Epoch 91/100
# 340/340 [==============================] - 0s 447us/step - loss: 10.4965
# Epoch 92/100
# 340/340 [==============================] - 0s 450us/step - loss: 12.6896
# Epoch 93/100
# 340/340 [==============================] - 0s 453us/step - loss: 17.1195
# Epoch 94/100
# 340/340 [==============================] - 0s 447us/step - loss: 17.5921
# Epoch 95/100
# 340/340 [==============================] - 0s 450us/step - loss: 12.3977
# Epoch 96/100
# 340/340 [==============================] - 0s 450us/step - loss: 11.9166
# Epoch 97/100
# 340/340 [==============================] - 0s 450us/step - loss: 11.9798
# Epoch 98/100
# 340/340 [==============================] - 0s 450us/step - loss: 15.8659
# Epoch 99/100
# 340/340 [==============================] - 0s 447us/step - loss: 11.7153
# Epoch 100/100
# 340/340 [==============================] - 0s 453us/step - loss: 10.7837

# %%
# IBM
print('Starting Groovy RNN MAPE - IBM using ', train_data_columns)
rnn, scaler = build_groovy()

train_scale, test_scale, scaler = data_prep(full_ibm_train, full_ibm_test, scaler, train_data_columns)
x_train, y_train = get_xy_train_sets(train_scale)
x_test, y_test = get_xy_test_sets(test_scale, full_ibm_test)

rnn = train(rnn, epochs, batch_size)
y_preds = predict(rnn, x_test, scaler)

plot_results(y_preds, y_test, 'Groovy MAPE - IBM using ' + str(test_data_column))

multi_preds.append(y_preds)
multi_titles.append('Groovy')
# Out:
# Starting Groovy RNN MAPE - IBM using  ['high']
# Epoch 1/100
# 340/340 [==============================] - 2s 6ms/step - loss: 72.3978
# Epoch 2/100
# 340/340 [==============================] - 1s 2ms/step - loss: 36.4502
# Epoch 3/100
# 340/340 [==============================] - 1s 2ms/step - loss: 20.5463
# Epoch 4/100
# 340/340 [==============================] - 1s 2ms/step - loss: 19.6669
# Epoch 5/100
# 340/340 [==============================] - 1s 2ms/step - loss: 19.1156
# Epoch 6/100
# 340/340 [==============================] - 1s 2ms/step - loss: 22.6916
# Epoch 7/100
# 340/340 [==============================] - 1s 2ms/step - loss: 16.1667
# Epoch 8/100
# 340/340 [==============================] - 1s 2ms/step - loss: 25.0830
# Epoch 9/100
# 340/340 [==============================] - 1s 2ms/step - loss: 17.0425
# Epoch 10/100
# 340/340 [==============================] - 1s 2ms/step - loss: 20.9792
# Epoch 11/100
# 340/340 [==============================] - 1s 2ms/step - loss: 15
100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.0353
# Epoch 99/100
# 340/340 [==============================] - 1s 2ms/step - loss: 13.1723
# Epoch 100/100
# 340/340 [==============================] - 1s 2ms/step - loss: 10.4573

# %%
# IBM
print('Starting Loovy RNN MAPE - IBM using ', train_data_columns)
rnn, scaler = build_loovy()

train_scale, test_scale, scaler = data_prep(full_ibm_train, full_ibm_test, scaler, train_data_columns)
x_train, y_train = get_xy_train_sets(train_scale)
x_test, y_test = get_xy_test_sets(test_scale, full_ibm_test)

rnn = train(rnn, epochs, batch_size)
y_preds = predict(rnn, x_test, scaler)

plot_results(y_preds, y_test, 'Loovy MAPE - IBM using ' + str(test_data_column))

multi_preds.append(y_preds)
multi_titles.append('Loovy')
# Out:
# Starting Loovy RNN MAPE - IBM using  ['high']
# Epoch 1/100
# 340/340 [==============================] - 2s 6ms/step - loss: 71.5917
# Epoch 2/100
# 340/340 [==============================] - 1s 3ms/step - loss: 39.3406
# Epoch 3/100
# 340/340 [==============================] - 1s 3ms/step - loss: 25.5717
# Epoch 4/100
# 340/340 [==============================] - 1s 3ms/step - loss: 22.6749
# Epoch 5/100
# 340/340 [==============================] - 1s 3ms/step - loss: 23.0968
# Epoch 6/100
# 340/340 [==============================] - 1s 3ms/step - loss: 24.0440
# Epoch 7/100
# 340/340 [==============================] - 1s 3ms/step - loss: 19.5978
# Epoch 8/100
# 340/340 [==============================] - 1s 3ms/step - loss: 27.3924
# Epoch 9/100
# 340/340 [==============================] - 1s 3ms/step - loss: 24.6823
# Epoch 10/100
# 340/340 [==============================] - 1s 3ms/step - loss: 24.2341
# Epoch 11/100
# 340/340 [==============================] - 1s 3ms/step - loss: 22.0697
# Epoch 12/100
# 340/340 [==============================] - 1s 3ms/step - loss: 26.1210
# Epoch 13/100
# 340/340 [==============================] - 1s 3ms/step - loss: 20.4303
# Epoch 14/100
# 340/340 [==============================] - 1s 3ms/step - loss: 23.7564
# Epoch 15/100
# 340/340 [==============================] - 1s 3ms/step - loss: 17.9209
# Epoch 16/100
# 340/340 [==============================] - 1s 3ms/step - loss: 24.7001
# Epoch 17/100
# 340/340 [==============================] - 1s 3ms/step - loss: 21.8587
# Epoch 18/100
# 340/340 [==============================] - 1s 3ms/step - loss: 18.6370
# Epoch 19/100
# 340/340 [==============================] - 1s 3ms/step - loss: 21.7653
# Epoch 20/100
# 340/340 [==============================] - 1s 3ms/step - loss: 20.2208
# Epoch 21/100
# 340/340 [==============================] - 1s 3ms/step - loss: 22.7950
# Epoch 22/100
# 340/340 [==============================] - 1s 3ms/step - loss: 16.4265
# Epoch 23/100
# 340/340 [==============================] - 1s 3ms/step - loss: 18.6135
# Epoch 24/100
# 340/340 [==============================] - 1s 3ms/step - loss: 19.1086
# Epoch 25/100
# 340/340 [==============================] - 1s 3ms/step - loss: 21.1447
# Epoch 26/100
# 340/340 [==============================] - 1s 3ms/step - loss: 19.7815
# Epoch 27/100
# 340/340 [==============================] - 1s 3ms/step - loss: 19.4555
# Epoch 28/100
# 340/340 [==============================] - 1s 3ms/step - loss: 19.2633
# Epoch 29/100
# 340/340 [==============================] - 1s 3ms/step - loss: 18.7514
# Epoch 30/100
# 340/340 [==============================] - 1s 3ms/step - loss: 16.7860
# Epoch 31/100
# 340/340 [==============================] - 1s 3ms/step - loss: 17.4735
# Epoch 32/100
# 340/340 [==============================] - 1s 3ms/step - loss: 18.9416
# Epoch 33/100
# 340/340 [==============================] - 1s 3ms/step - loss: 19.5033
# Epoch 34/100
# 340/340 [==============================] - 1s 3ms/step - loss: 17.6656
# Epoch 35/100
# 340/340 [==============================] - 1s 3ms/step - loss: 14.8016
# Epoch 36/100
# 340/340 [==============================] - 1s 3ms/step - loss: 16.2082
# Epoch 37/100
# 340/340 [==============================] - 1s 3ms/step - loss: 17.7641
# Epoch 38/100
# 340/340 [==============================] - 1s 3ms/step - loss: 17
100
# 340/340 [==============================] - 1s 3ms/step - loss: 14.2121
# Epoch 98/100
# 340/340 [==============================] - 1s 3ms/step - loss: 14.3299
# Epoch 99/100
# 340/340 [==============================] - 1s 3ms/step - loss: 16.8229
# Epoch 100/100
# 340/340 [==============================] - 1s 3ms/step - loss: 13.3444

# %%
# IBM
print('Starting Super Groovy RNN MAPE - IBM using ', train_data_columns)
rnn, scaler = build_super_groovy()

train_scale, test_scale, scaler = data_prep(full_ibm_train, full_ibm_test, scaler, train_data_columns)
x_train, y_train = get_xy_train_sets(train_scale)
x_test, y_test = get_xy_test_sets(test_scale, full_ibm_test)

rnn = train(rnn, epochs, batch_size)
y_preds = predict(rnn, x_test, scaler)

plot_results(y_preds, y_test, 'Super Groovy MAPE - IBM using ' + str(test_data_column))

multi_preds.append(y_preds)
multi_titles.append('SGroovy')
# Out:
# Starting Super Groovy RNN MAPE - IBM using  ['high']
# Epoch 1/100
# 340/340 [==============================] - 4s 12ms/step - loss: 77.7726
# Epoch 2/100
# 340/340 [==============================] - 1s 4ms/step - loss: 44.1485
# Epoch 3/100
# 340/340 [==============================] - 1s 4ms/step - loss: 27.9164
# Epoch 4/100
# 340/340 [==============================] - 1s 4ms/step - loss: 22.5631
# Epoch 5/100
# 340/340 [==============================] - 1s 4ms/step - loss: 28.2554
# Epoch 6/100
# 340/340 [==============================] - 1s 4ms/step - loss: 24.7122
# Epoch 7/100
# 340/340 [==============================] - 1s 4ms/step - loss: 25.4413
# Epoch 8/100
# 340/340 [==============================] - 1s 4ms/step - loss: 18.2495
# Epoch 9/100
# 340/340 [==============================] - 1s 4ms/step - loss: 18.4044
# Epoch 10/100
# 340/340 [==============================] - 1s 4ms/step - loss: 38.4283
# Epoch 11/100
# 340/340 [==============================] - 1s 4ms/step - loss: 17.7320
# Epoch 12/100
# 340/340 [==============================] - 1s 4ms/step - loss: 28.7851
# Epoch 13/100
# 340/340 [==============================] - 1s 4ms/step - loss: 17.5855
# Epoch 14/100
# 340/340 [==============================] - 1s 4ms/step - loss: 20.1079
# Epoch 15/100
# 340/340 [==============================] - 1s 4ms/step - loss: 20.9473
# Epoch 16/100
# 340/340 [==============================] - 1s 4ms/step - loss: 16.8102
# Epoch 17/100
# 340/340 [==============================] - 1s 4ms/step - loss: 21.7958
# Epoch 18/100
# 340/340 [==============================] - 1s 4ms/step - loss: 24.4915
# Epoch 19/100
# 340/340 [==============================] - 1s 4ms/step - loss: 27.5391
# Epoch 20/100
# 340/340 [==============================] - 1s 4ms/step - loss: 17.0748
# Epoch 21/100
# 340/340 [==============================] - 1s 4ms/step - loss: 24.1344
# Epoch 22/100
# 340/340 [==============================] - 1s 4ms/step - loss: 19.9496
# Epoch 23/100
# 340/340 [==============================] - 1s 4ms/step - loss: 17.2196
# Epoch 24/100
# 340/340 [==============================] - 1s 4ms/step - loss: 19.2297
# Epoch 25/100
# 340/340 [==============================] - 1s 4ms/step - loss: 19.5857
# Epoch 26/100
# 340/340 [==============================] - 1s 4ms/step - loss: 21.4270
# Epoch 27/100
# 340/340 [==============================] - 1s 4ms/step - loss: 14.8753
# Epoch 28/100
# 340/340 [==============================] - 1s 4ms/step - loss: 14.8415
# Epoch 29/100
# 340/340 [==============================] - 1s 4ms/step - loss: 26.6771
# Epoch 30/100
# 340/340 [==============================] - 1s 4ms/step - loss: 16.0792
# Epoch 31/100
# 340/340 [==============================] - 1s 4ms/step - loss: 20.6335
# Epoch 32/100
# 340/340 [==============================] - 1s 4ms/step - loss: 15.6138
# Epoch 33/100
# 340/340 [==============================] - 1s 4ms/step - loss: 14
100
# 340/340 [==============================] - 1s 4ms/step - loss: 15.4016
# Epoch 95/100
# 340/340 [==============================] - 1s 4ms/step - loss: 11.3998
# Epoch 96/100
# 340/340 [==============================] - 1s 4ms/step - loss: 15.4459
# Epoch 97/100
# 340/340 [==============================] - 1s 4ms/step - loss: 12.5664
# Epoch 98/100
# 340/340 [==============================] - 1s 4ms/step - loss: 14.0774
# Epoch 99/100
# 340/340 [==============================] - 1s 4ms/step - loss: 16.5292
# Epoch 100/100
# 340/340 [==============================] - 1s 4ms/step - loss: 10.6043

# %%
# IBM
print('Starting Super Loovy RNN MAPE - IBM using ', train_data_columns)
rnn, scaler = build_super_loovy()

train_scale, test_scale, scaler = data_prep(full_ibm_train, full_ibm_test, scaler, train_data_columns)
x_train, y_train = get_xy_train_sets(train_scale)
x_test, y_test = get_xy_test_sets(test_scale, full_ibm_test)

rnn = train(rnn, epochs, batch_size)
y_preds = predict(rnn, x_test, scaler)

plot_results(y_preds, y_test, 'Super Loovy MAPE - IBM using ' + str(test_data_column))

multi_preds.append(y_preds)
multi_titles.append('SLoovy')
# Out:
# Starting Super Loovy RNN MAPE - IBM using  ['high']
# Epoch 1/100
# 340/340 [==============================] - 4s 12ms/step - loss: 95.7876
# Epoch 2/100
# 340/340 [==============================] - 2s 5ms/step - loss: 42.9002
# Epoch 3/100
# 340/340 [==============================] - 2s 5ms/step - loss: 25.4818
# Epoch 4/100
# 340/340 [==============================] - 2s 5ms/step - loss: 25.7678
# Epoch 5/100
# 340/340 [==============================] - 2s 5ms/step - loss: 29.2305
# Epoch 6/100
# 340/340 [==============================] - 2s 5ms/step - loss: 25.3866
# Epoch 7/100
# 340/340 [==============================] - 2s 5ms/step - loss: 24.7786
# Epoch 8/100
# 340/340 [==============================] - 2s 5ms/step - loss: 33.8879
# Epoch 9/100
# 340/340 [==============================] - 2s 5ms/step - loss: 30.6112
# Epoch 10/100
# 340/340 [==============================] - 2s 5ms/step - loss: 24.5348
# Epoch 11/100
# 340/340 [==============================] - 2s 5ms/step - loss: 33.3256
# Epoch 12/100
# 340/340 [==============================] - 2s 5ms/step - loss: 26.3367
# Epoch 13/100
# 340/340 [==============================] - 2s 5ms/step - loss: 34.4570
# Epoch 14/100
# 340/340 [==============================] - 2s 5ms/step - loss: 26.6878
# Epoch 15/100
# 340/340 [==============================] - 2s 5ms/step - loss: 24.0540
# Epoch 16/100
# 340/340 [==============================] - 2s 5ms/step - loss: 27.1519
# Epoch 17/100
# 340/340 [==============================] - 2s 5ms/step - loss: 25.8225
# Epoch 18/100
# 340/340 [==============================] - 2s 5ms/step - loss: 24.7487
# Epoch 19/100
# 340/340 [==============================] - 2s 5ms/step - loss: 43.1213
# Epoch 20/100
# 340/340 [==============================] - 2s 5ms/step - loss: 24.9869
# Epoch 21/100
# 340/340 [==============================] - 2s 5ms/step - loss: 27.8166
# Epoch 22/100
# 340/340 [==============================] - 2s 5ms/step - loss: 30.6763
# Epoch 23/100
# 340/340 [==============================] - 2s 5ms/step - loss: 28.1748
# Epoch 24/100
